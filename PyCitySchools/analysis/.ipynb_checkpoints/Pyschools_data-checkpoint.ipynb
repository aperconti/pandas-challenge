# %% [markdown]
# # Data Findings
#
#
# ### Number of students:
# The data shows a strong correlation to charter schools having a higher overall passing rate than public school districts.
#
# ### Size of schools:
# After consulting the Pyschools data, there is a clear trend showing higher student numbers in public school districts than in Charter schools.
#
# ### Reading vs. Math scores:
# In this data set, the average reading scores are higher than average math scores across all school sizes. This trend continues based on spending per student, showing a higher passing rate in reading regardless of higher per-student spending and vice versa.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load 
school_data_loaded = "../Resources/School.csv"
student_data_loaded = "../Resources/Students.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_loaded)
student_data = pd.read_csv(student_data_loaded)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

#Calculate the total number of schools
school_count = school_data_complete["School ID"].nunique()
print(f'Total Schools: {school_count}')

#Calculate the total number of students
student_count = school_data_complete["Student ID"].nunique()
print(f'Total Students: {student_count}')

# #Calculate the total budget
budgets = school_data_complete.loc[school_data_complete["Student ID"]]["budget"]
total_budget = budgets.unique().sum()

#applying currency function to budget column in 'school_data_complete'
school_data_complete['budget'] = school_data_complete['budget'] #.apply(currency_format)

#Calculate the average math score
math_score = school_data_complete["math_score"]
math_average = math_score.mean()
total_math_av = round(math_average,6)
print(f'Average Math Score: {total_math_av}')

#Calculate the average reading score
reading_score = school_data_complete["reading_score"]
reading_score = reading_score.mean()
total_reading_av = round(reading_score, 6)
print(f'Average Reading Score: {total_reading_av}')


#Calculate the overall passing rate 
overall_av_score = (total_reading_av + total_math_av) / 2
overall_av_score_r = round(overall_av_score,6)
print(f'% Overall Passing Rate: {overall_av_score_r}')

#Passing math score (70 or greater)
math_passing = school_data_complete["math_score"] >= 70
true_count = sum(math_passing)
passing_math_score = round((true_count/student_count)*100,6)
print(f'% Passing Math: {passing_math_score}')

#passing reading score (70 or greater)
reading_passing = school_data_complete["reading_score"] >= 70
true_count_reading = sum(reading_passing)
passing_reading_score = round((true_count_reading/student_count)*100,6)
print(f'% Passing Reading: {passing_reading_score}')

#creating a dataframe 
#input variables 
district_summary = [school_count, student_count,total_budget, total_math_av, overall_av_score_r, total_reading_av, passing_math_score, passing_reading_score] 
#dataframe columns
df = pd.DataFrame([district_summary], columns =['Total Schools','Total Students','Total Budget', 'Average Math Score', 'Average Reading Score','% Passing Math', '% Passing Reading', '% Overall Passing Rate']) 

#show dataframe
school_data_complete
# Out:
# Total Schools: 15
# Total Students: 39170
# Average Math Score: 78.985371
# Average Reading Score: 81.87784
# % Overall Passing Rate: 80.431606
# % Passing Math: 74.980853
# % Passing Reading: 85.805463
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# ...

# %%
# Overview table

# Get unique rows
grouped_overview_table = school_data_complete.drop_duplicates(subset = ["school_name"])

# Remove unused columns
unused_columns = ['Student ID', 'math_score', 'student_name', 'gender', 'grade', 'reading_score']
grouped_overview_table = grouped_overview_table.drop(unused_columns, axis=1)

# Assign School Name as Index
grouped_overview_table = grouped_overview_table.drop(['School ID'], axis=1)

# Rename column names
grouped_overview_table.columns = ['School Name', 'School Type', 'Total Students', 'Total School Budget']
grouped_overview_table = grouped_overview_table.reset_index(drop=True)

# Create Per Student Budget
grouped_overview_table['Per Student Budget'] = grouped_overview_table['Total School Budget'] / grouped_overview_table['Total Students']

# Create Average Math Score
student_mean_math_df = student_data.groupby('school_name')['math_score'].mean()
#grouped_overview_table = grouped_overview_table.merge(student_mean_math_df, left_on='School Name', right_on='school_name')


""" 
===========================================
START Create Average Reading Score
===========================================
"""
student_mean_reading_df = student_data.groupby('school_name')['math_score'].mean()
grouped_overview_table = grouped_overview_table.merge(student_mean_reading_df, left_on='School Name', right_on='school_name')
grouped_overview_table.columns = ['School Name', 'School Type', 'Total Students', 'Total School Budget', 'Per Student Budget', 'Average Math Score']
""" 
===========================================
END Create Average Reading Score
===========================================
"""


""" 
===========================================
START Create Average Reading Score
===========================================
"""
student_mean_reading_df = student_data.groupby('school_name')['reading_score'].mean()
grouped_overview_table = grouped_overview_table.merge(student_mean_reading_df, left_on='School Name', right_on='school_name')
grouped_overview_table.columns = ['School Name', 'School Type', 'Total Students', 'Total School Budget', 'Per Student Budget', 'Average Math Score', 'Average Reading Score']
""" 
===========================================
END Create Average Reading Score
===========================================
"""

""" 
===========================================
START Creation of the % Passing Math Column
===========================================
"""
# Get table of total number of students in each school (size of school)
student_size_math_df = student_data.groupby('school_name')['math_score'].size()

# Get table that meet passing criteria (students who scored 70 or above in math)
student_mean_math_df = student_data.groupby('school_name')['math_score'].apply(lambda x: x >= 70)

# Count the number of students who passed, grouped by each school
student_math_count = student_data[student_mean_math_df].groupby('school_name')['math_score'].count()

# Divide number of students who passed by total number of students, grouped by school
raw_percentage_passing = student_math_count.div(student_size_math_df) * 100

# Add results to the overview table
grouped_overview_table = grouped_overview_table.merge(raw_percentage_passing, left_on='School Name', right_on='school_name')

# Clean up unused columns
grouped_overview_table.columns = ['School Name', 'School Type', 'Total Students', 'Total School Budget', 'Per Student Budget', 'Average Math Score', 'Average Reading Score', '% Passing Math']
""" 
=========================================
END Creation of the % Passing Math Column
=========================================
"""

""" 
==============================================
START Creation of the % Passing Reading Column
==============================================
"""
# Get table of total number of students in each school (size of school)
student_size_reading_df = student_data.groupby('school_name')['reading_score'].size()
# Get table that meet passing criteria (students who scored 70 or above in math)
student_mean_reading_df = student_data.groupby('school_name')['reading_score'].apply(lambda x: x >= 70)

# Count the number of students who passed, grouped by each school
student_reading_count = student_data[student_mean_reading_df].groupby('school_name')['reading_score'].count()

# Divide number of students who passed by total number of students, grouped by school
raw_percentage_passing = student_reading_count.div(student_size_reading_df) * 100

# Add results to the overview table
grouped_overview_table = grouped_overview_table.merge(raw_percentage_passing, left_on='School Name', right_on='school_name')

# Clean up unused columns
grouped_overview_table.columns = ['School Name', 'School Type', 'Total Students', 'Total School Budget', 'Per Student Budget', 'Average Math Score', 'Average Reading Score', '% Passing Math', '% Passing Reading']

""" 
============================================
END Creation of the % Passing Reading Column
============================================
"""

""" 
==============================================
START Creation of the Overall Passing Rate (Average of the above two)
==============================================
"""
grouped_overview_table["% Overall Passing Rate"] = ( grouped_overview_table["% Passing Reading"] + grouped_overview_table["% Passing Math"] ) / 2
""" 
============================================
END Creation of the % Passing Reading Column
============================================
"""
#reset index
grouped_overview_table.set_index('School Name', inplace=True)

grouped_overview_table
# Out:
#                       School Type  Total Students  Total School Budget  \
# School Name
# Huang High School        District            2917              1910635
# Figueroa High School     District            2949              1884411
# Shelton High School       Charter            1761              1056600
# Hernandez High School    District            4635              3022020
# Griffin High School       Charter            1468               917500
# Wilson High School        Charter            2283              1319574
# Cabrera High School       Charter            1858              1081356
# Bailey High School       District            4976              3124928
# Holden High School        Charter             427               248087
# Pena High School          Charter             962               585858
# Wright High School        Charter            1800              1049400
# Rodriguez High School    District            3999              2547363
# ...

# %%
grouped_overview_table.sort_values(['% Overall Passing Rate'],ascending = False).head(5)
# Out:
#                     School Type  Total Students  Total School Budget  \
# School Name
# Cabrera High School     Charter            1858              1081356
# Thomas High School      Charter            1635              1043130
# Pena High School        Charter             962               585858
# Griffin High School     Charter            1468               917500
# Wilson High School      Charter            2283              1319574
#
#                      Per Student Budget  Average Math Score  \
# School Name
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Pena High School                  609.0           83.839917
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# School Name
# ...

# %%
grouped_overview_table.sort_values(['% Overall Passing Rate'],ascending = True).head(5)
# Out:
#                       School Type  Total Students  Total School Budget  \
# School Name
# Rodriguez High School    District            3999              2547363
# Figueroa High School     District            2949              1884411
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Ford High School         District            2739              1763916
#
#                        Per Student Budget  Average Math Score  \
# School Name
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Johnson High School                 650.0           77.072464
# Ford High School                    644.0           77.102592
#
#                        Average Reading Score  % Passing Math  \
# School Name
# ...

# %%
#groupby school, grade, and reading score. 
cleaned_data = student_data.groupby(['school_name', 'grade'])['math_score'].mean().to_frame()

#unstacking data formatting it to horizontal vs vertical 
cleaned_data_unstacked = cleaned_data['math_score'].unstack()


#column names in the order that we want
cols = ['9th', '10th', '11th', '12th']

#setting column names on unstacked data
cleaned_data_unstacked = cleaned_data_unstacked[cols]

#removing school name index title
cleaned_data_unstacked.index.name = None

#removing grade column title
cleaned_data_unstacked.columns.name = None

#showing dataframe
cleaned_data_unstacked
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
#groupby school, grade, and reading score. 
cleaned_data = student_data.groupby(['school_name', 'grade'])['reading_score'].mean().to_frame()

#unstacking data formatting it to horizontal vs vertical 
cleaned_data_unstacked = cleaned_data['reading_score'].unstack()


#column names in the order that we want
cols = ['9th', '10th', '11th', '12th']

#setting column names on unstacked data
cleaned_data_unstacked = cleaned_data_unstacked[cols]

#removing school name index title
cleaned_data_unstacked.index.name = None

#removing grade column title
cleaned_data_unstacked.columns.name = None

#showing dataframe
cleaned_data_unstacked
# Out:
#                              9th       10th       11th       12th
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %%
#Creating bins and labels
spending_bins = [0, 585, 615, 645, 675]
labels_names = ["<$585", "$585-615", "$615-645", "$645-675"]

#creating copy of original dataframe 
data_grouped = grouped_overview_table

#putting data in bins and adding column
data_grouped["Spending Ranges (Per Student)"] = pd.cut(grouped_overview_table2["Per Student Budget"], bins=spending_bins, labels=labels_names)

#grouping by'Spending Ranges (Per Student)'
#caluculating mean of math average
#converting math average mean to dataFrame
math_av = data_grouped.groupby("Spending Ranges (Per Student)")["Average Math Score"].mean().to_frame()

#grouping by 'Spending Ranges (Per Student)'
#caluculating mean of reading average
#converting reading average to dataFrame
reading_av = data_grouped.groupby("Spending Ranges (Per Student)")["Average Reading Score"].mean().to_frame()

#grouping by 'Spending Ranges (Per Student)'
#caluculating mean of percent of students that passed math
#converting average of percent of students that passed math to dataFrame
math_pass = data_grouped.groupby("Spending Ranges (Per Student)")["% Passing Math"].mean().to_frame()

#grouping by 'Spending Ranges (Per Student)'
#caluculating mean of percent of students that passed reading
#converting average of percent of students that passed reading to dataFrame
reading_pass = data_grouped.groupby("Spending Ranges (Per Student)")["% Passing Reading"].mean().to_frame()

#merging math_av and reading_av
combined_grouped_overview_table1= pd.merge(math_av, reading_av,
                                 how='outer', on='Spending Ranges (Per Student)')
#merging math_pass and reading_pass
combined_grouped_overview_table2 = pd.merge(math_pass, reading_pass,
                                 how='outer', on='Spending Ranges (Per Student)')

#merging combined_grouped_overview_table1 and combined_grouped_overview_table2 
combined_data = pd.merge(combined_grouped_overview_table1, combined_grouped_overview_table2,
                                 how='outer', on='Spending Ranges (Per Student)')


#calculating percent of overall pass rate and adding column with data to 'complete_combined_data' 
combined_data["% Overall Passing Rate"] = (combined_data["% Passing Math"] + combined_data["% Passing Reading"])/2

#showing dataFrame
combined_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-038a0fadc129> in <module>
#       7
#       8 #putting data in bins and adding column
# ----> 9 data_grouped["Spending Ranges (Per Student)"] = pd.cut(grouped_overview_table2["Per Student Budget"], bins=spending_bins, labels=labels_names)
#      10
#      11 #grouping by'Spending Ranges (Per Student)'
#
# NameError: name 'grouped_overview_table2' is not defined

# %%
# Creating bins and labels 
bins = [0, 1000, 2000, 5000]
groups = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

#creating copy of original dataframe  
data = grouped_overview_table

#putting data in bins and adding column 
data["School Size"] = pd.cut(data["Total Students"], bins=bins, labels=groups)

#grouping by school size
#caluculating mean of math average
#converting math average mean to dataFrame
math_av = data.groupby("School Size")["Average Math Score"].mean().to_frame()

#grouping by school size
#caluculating mean of reading average
#converting reading average to dataFrame
reading_av = data.groupby("School Size")["Average Reading Score"].mean().to_frame()

#grouping by school size
#caluculating mean of percent of students that passed math
#converting average of percent of students that passed math to dataFrame
math_pass = data.groupby("School Size")["% Passing Math"].mean().to_frame()

#grouping by school size
#caluculating mean of percent of students that passed reading
#converting average of percent of students that passed reading to dataFrame
reading_pass = data.groupby("School Size")["% Passing Reading"].mean().to_frame()

#merging math_av and reading_av 
combined_data1 = pd.merge(math_av, reading_av, how='outer', on='School Size')

#merging math_pass and reading_pass
combined_data2 = pd.merge(math_pass, reading_pass, how='outer', on='School Size')

#merging combined_grouped_overview_table1 and combined_grouped_overview_table2
#merging data on School Size 
complete_combined_data = pd.merge(combined_data1, combined_data2, how='outer', on='School Size')

#calculating percent of overall pass rate and adding column with data to 'complete_combined_data' 
complete_combined_data["% Overall Passing Rate"] = (complete_combined_data["% Passing Math"] + complete_combined_data["% Passing Reading"])/2

#showing dataFrame
complete_combined_data
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing Rate
# School Size
# Small (<1000)               96.099437               94.824831
# Medium (1000-2000)          96.790680               95.195187
# Large (2000-5000)           82.766634               76.364998

# %%
#creating copy of original dataframe  
data_of_type = grouped_overview_table


#grouping by'School Type'
#caluculating mean of math average
#converting math average mean to dataFrame
math_av = data_of_type.groupby("School Type")["Average Math Score"].mean().to_frame()


#grouping by'School Type'
#caluculating mean of reading average
#converting reading average to dataFrame
reading_av = data_of_type.groupby("School Type")["Average Reading Score"].mean().to_frame()


#grouping by'School Type'
#caluculating mean of percent of students that passed math
#converting average of percent of students that passed math to dataFrame
math_pass = data_of_type.groupby("School Type")["% Passing Math"].mean().to_frame()

#grouping by 'School Type'
#caluculating mean of percent of students that passed reading
#converting average of percent of students that passed reading to dataFrame
reading_pass = data_of_type.groupby("School Type")["% Passing Reading"].mean().to_frame()


#merging math_av and reading_av 
combined_data1 = pd.merge(math_av, reading_av, how='outer', on='School Type')

#merging math_pass and reading_pass
combined_data2 = pd.merge(math_pass, reading_pass, how='outer', on='School Type')

#merging combined_grouped_overview_table1 and combined_grouped_overview_table2
#merging data on School Size 
complete_combined_data_type = pd.merge(combined_data1, combined_data2, how='outer', on='School Type')

#calculating percent of overall pass rate and adding column with data to 'complete_combined_data_type' 
complete_combined_data_type["% Overall Passing Rate"] = (complete_combined_data_type["% Passing Math"] + complete_combined_data_type["% Passing Reading"])/2
 
#showing dataFrame
complete_combined_data_type
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing Rate
# School Type
# Charter              96.586489               95.103660
# District             80.799062               73.673757

# %%
#############
#visuals
############

plotting_av_scores_by_school = grouped_overview_table[['Average Math Score','Average Reading Score']]
reset = plotting_av_scores_by_school.reset_index()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from io import StringIO

ax = reset.plot(kind='bar', x='School Name', color=['#b4c6db', '#002a4e'])
ax.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.legend(loc="upper center")
ax.margins(.3)
plt.savefig('average_math_reading.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plot_data = complete_combined_data_type[['Average Math Score', 'Average Reading Score']]
reset_plot_data = plot_data.reset_index()
reset_plot_data
# Out:
#   School Type  Average Math Score  Average Reading Score
# 0     Charter           83.473852              83.896421
# 1    District           76.956733              80.966636

# %%
ax = reset_plot_data.plot(kind='line', x='School Type', color=['#b4c6db', '#002a4e'])
# ax.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.legend(loc="upper center")
ax.margins(.3)
plt.savefig('school_type.png', dpi=300, bbox_inches='tight')
plt.show()
